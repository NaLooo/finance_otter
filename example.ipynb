# %%
import financeotter as fo
import financeotter.famafrench as ff

ticker = fo.get_ticker('aapl')

ticker.history('max')
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 1980-12-12    0.128348    0.128906    0.128348    0.128348    0.099584
# 1980-12-15    0.122210    0.122210    0.121652    0.121652    0.094388
# 1980-12-16    0.113281    0.113281    0.112723    0.112723    0.087461
# 1980-12-17    0.115513    0.116071    0.115513    0.115513    0.089625
# 1980-12-18    0.118862    0.119420    0.118862    0.118862    0.092224
# ...                ...         ...         ...         ...         ...
# 2023-07-06  189.839996  192.020004  189.199997  191.809998  191.809998
# 2023-07-07  191.410004  192.669998  190.240005  190.679993  190.679993
# 2023-07-10  189.259995  189.990005  187.039993  188.610001  188.610001
# 2023-07-11  189.160004  189.300003  186.600006  188.080002  188.080002
# 2023-07-12  189.679993  191.699997  188.470001  189.770004  189.770004
#
#                  Volume
# Date
# 1980-12-12  469033600.0
# 1980-12-15  175884800.0
# 1980-12-16  105728000.0
# ...

# %%
ticker = fo.get_ticker('cost')
result = ff.OLS_ff3_daily(ticker)

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.458
# Model:                            OLS   Adj. R-squared:                  0.450
# Method:                 Least Squares   F-statistic:                     61.30
# Date:                Thu, 13 Jul 2023   Prob (F-statistic):           8.86e-29
# Time:                        00:27:17   Log-Likelihood:                 662.83
# No. Observations:                 222   AIC:                            -1318.
# Df Residuals:                     218   BIC:                            -1304.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0138      0.001    -16.611      0.000      -0.015      -0.012
# ...
