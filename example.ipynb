# %%
import financeotter as fo
import financeotter.famafrench as ff
import pandas as pd

from financeotter.models import ARMA
from datetime import datetime

arr = ['aapl', 'goog', 'msft', 'amzn', 'bili', 'iq', 'coke', 'tsla', 'amc']
results = []

for t in arr:
    ticker = fo.get_ticker(t)
    results.append(ff.OLS_ff3_daily(ticker))

# %%
results[8].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.294
# Model:                            OLS   Adj. R-squared:                  0.285
# Method:                 Least Squares   F-statistic:                     30.56
# Date:                Thu, 06 Apr 2023   Prob (F-statistic):           1.48e-16
# Time:                        10:30:13   Log-Likelihood:                 307.03
# No. Observations:                 224   AIC:                            -606.1
# Df Residuals:                     220   BIC:                            -592.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0116      0.004     -2.789      0.006      -0.020      -0.003
# ...

# %%
t = fo.get_ticker('cost')
result = ff.OLS_ff3_daily(t)

result.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.497
# Model:                            OLS   Adj. R-squared:                  0.490
# Method:                 Least Squares   F-statistic:                     72.50
# Date:                Thu, 06 Apr 2023   Prob (F-statistic):           1.21e-32
# Time:                        10:35:58   Log-Likelihood:                 622.02
# No. Observations:                 224   AIC:                            -1236.
# Df Residuals:                     220   BIC:                            -1222.
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0092      0.001     -9.042      0.000      -0.011      -0.007
# ...
